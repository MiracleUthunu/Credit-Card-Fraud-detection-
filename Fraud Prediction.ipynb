# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fraud = pd.read_csv('fraud test.csv')

# %%
fraud.head()
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      21/06/2020 12:14  2.291160e+15
# 1           1      21/06/2020 12:14  3.573030e+15
# 2           2      21/06/2020 12:14  3.598220e+15
# 3           3      21/06/2020 12:15  3.591920e+15
# 4           4      21/06/2020 12:15  3.526830e+15
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# 1  Williams      F             3638 Marsh Union  ...  40.3207 -110.4360
# ...

# %%
fraud.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800430e+14       9.630000   26292.000000
# 50%    277859.000000  3.521420e+15      47.290000   48174.000000
# 75%    416788.500000  4.635330e+15      83.010000   72011.000000
# max    555718.000000  4.992350e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
number_feat = fraud.drop("is_fraud", axis=1).columns
fraud[number_feat].hist(bins=20, figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'cc_num'}>,
#         <Axes: title={'center': 'amt'}>],
#        [<Axes: title={'center': 'zip'}>, <Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>],
#        [<Axes: title={'center': 'city_pop'}>,
#         <Axes: title={'center': 'unix_time'}>,
#         <Axes: title={'center': 'merch_lat'}>],
#        [<Axes: title={'center': 'merch_long'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.pairplot(fraud)
# Out:
# C:\anacondaaaa\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
fraud.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
fraud['merchants'] = encoder.fit_transform(fraud['merchant'])
fraud['categorys'] = encoder.fit_transform(fraud['category'])
fraud['DOB'] = encoder.fit_transform(fraud['dob'])
fraud['JOB'] = encoder.fit_transform(fraud['job'])
fraud['trans_date'] = encoder.fit_transform(fraud['trans_date_trans_time'])
fraud['trans_details'] = encoder.fit_transform(fraud['trans_num'])

# %%
fraud.drop(columns='merchant', axis=1, inplace=True)
fraud.drop(columns='category', axis=1, inplace=True)
fraud.drop(columns='dob', axis=1, inplace=True)
fraud.drop(columns='job', axis=1, inplace=True)
fraud.drop(columns='trans_num', axis=1, inplace=True)
fraud.drop(columns='trans_date_trans_time', axis=1, inplace=True)

fraud.head()
# Out:
#    Unnamed: 0        cc_num    amt   first      last gender  \
# 0           0  2.291160e+15   2.86    Jeff   Elliott      M
# 1           1  3.573030e+15  29.84  Joanne  Williams      F
# 2           2  3.598220e+15  41.28  Ashley     Lopez      F
# 3           3  3.591920e+15  60.05   Brian  Williams      M
# 4           4  3.526830e+15   3.19  Nathan    Massey      M
#
#                         street        city state    zip  ...   unix_time  \
# 0            351 Darlene Green    Columbia    SC  29209  ...  1371816865
# 1             3638 Marsh Union     Altonah    UT  84002  ...  1371816873
# 2         9333 Valentine Point    Bellmore    NY  11710  ...  1371816893
# 3  32941 Krystal Mill Apt. 552  Titusville    FL  32780  ...  1371816915
# 4     5783 Evan Roads Apt. 465    Falmouth    MI  49632  ...  1371816917
#
#    merch_lat  merch_long  is_fraud  merchants  categorys  DOB  JOB  \
# 0  33.986391  -81.200714         0        319         10  544  275
# ...

# %%
fraud.drop(columns='Unnamed: 0', axis=1, inplace=True)

# %%
x = fraud.drop(columns=['is_fraud', 'state', 'street', 'city', 'gender', 'last', 'first', 'unix_time', 'merch_lat','merch_long'])
y = fraud['is_fraud']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 555714    0
# 555715    0
# 555716    0
# 555717    0
# 555718    0
# Name: is_fraud, Length: 555719, dtype: int64

# %%
x
# Out:
#               cc_num     amt    zip      lat      long  city_pop  merchants  \
# 0       2.291160e+15    2.86  29209  33.9659  -80.9355    333497        319
# 1       3.573030e+15   29.84  84002  40.3207 -110.4360       302        591
# 2       3.598220e+15   41.28  11710  40.6729  -73.5365     34496        611
# 3       3.591920e+15   60.05  32780  28.5697  -80.8191     54767        222
# 4       3.526830e+15    3.19  49632  44.2529  -85.0170      1126        292
# ...              ...     ...    ...      ...       ...       ...        ...
# 555714  3.056060e+13   43.77  63453  40.4931  -91.8912       519        507
# 555715  3.556610e+15  111.84  77566  29.0393  -95.4401     28739        264
# 555716  6.011720e+15   86.88  99323  46.1966 -118.9017      3684        496
# 555717  4.079770e+12    7.99  83643  44.6255 -116.4493       129         75
# 555718  4.170690e+15   38.13  73034  35.6665  -97.4798    116001        125
#
#         categorys  DOB  JOB  trans_date  trans_details
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=40)

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
LR.fit(x_train, y_train)
# Out:
# C:\anacondaaaa\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = LR.predict(x_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score, mean_absolute_error

# %%
print("Acurracy:", accuracy_score(y_test, y_pred))
# Out:
# Acurracy: 0.9962451114470117

# %%
print("Confusion Matrix:", confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix: [[166090      0]
#  [   626      0]]

# %%
print("Precision:", precision_score(y_test, y_pred))
# Out:
# Precision: 0.0
# C:\anacondaaaa\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
min_length_train = min(len(x_train), len(y_train))
x_train = x_train[:min_length_train]
y_train = y_train[:min_length_train]

min_length_test = min(len(x_test), len(y_test))
x_test = x_test[:min_length_test]
y_test = y_test[:min_length_test]

# %%
mae = mean_absolute_error(y_test, y_pred)
print("MAE:" , mae)
# Out:
# MAE: 0.0037548885529883154

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rfc.predict(x_test)

# %%
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print("Acurracy:", accuracy_score(y_test, y_pred))
# Out:
# Acurracy: 0.9980985628254037

# %%
print("Precision:", precision_score(y_test, y_pred))
# Out:
# Precision: 0.8992248062015504

# %%
mae = mean_absolute_error(y_test, y_pred)
print("MAE:" , mae)
# Out:
# MAE: 0.0019014371745963196

# %%
import pickle as pkl

# %%
filename = 'Fraud test_Model.pkl'
pkl.dump(rfc, open(filename, 'wb'))
